# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#To get the average frame count
import json
import glob
import numpy as np
import cv2
import copy
#change the path accordingly
video_files =  glob.glob('/content/drive/MyDrive/Deepfake Detection/Dataset/*.mp4')
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [412, 272, 409, 469, 303, 350, 529, 326, 459, 534, 479, 464, 520, 519, 412, 445, 376, 361, 383, 425, 307, 380, 470, 516, 322, 458, 380, 428, 372, 499, 409, 361, 458, 497, 450, 415, 512, 295, 328, 450, 398, 463, 486, 474, 477, 575, 422, 470, 397, 474, 461, 371, 276, 400, 451, 409, 422, 505, 469, 272, 303, 400, 350, 451, 529, 422, 326, 505, 328, 459, 412, 365, 534, 272, 400, 479, 451, 409, 464, 422, 520, 505, 328, 469, 412, 303, 400, 350, 451, 409, 529, 422, 505, 464, 328, 520, 365, 272, 469, 400, 303, 451, 409, 350, 422, 529, 505, 328, 326, 412, 272, 459, 400, 451, 534, 409, 422, 479, 505, 328, 464, 412, 365, 520, 272, 400, 469, 451, 303, 409, 350, 422, 326, 505, 328, 459, 412, 272, 400, 534, 365, 272, 451, 400, 409, 520, 451, 422, 409, 469, 505, 422, 328, 303, 505, 412, 350, 328, 412, 534, 479, 520, 469, 303, 534, 479, 520, 469, 303, 350, 529, 459, 534, 479, 520, 469, 303, 350, 529, 326, 459, 534, 459, 479, 529, 350, 365, 365, 365, 365, 529, 459, 534, 479, 464, 520]
# Total number of videos:  196
# Average frame per video: 423.1683673469388

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path)
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
# !pip3 install face_recognition
# !mkdir '/content/drive/My Drive/FF_REAL_Face_only_data'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      #if(idx % 3 == 0):
      if(idx <= 150):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (19.24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from face_recognition) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face_recognition) (9.4.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=95437243fc3d198466c9356981a8d28b7c41748748e35903a2adb98cac4aa586
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face_recognition
# Successfully installed face-recognition-models-0.3.0 face_recognition-1.3.0
# mkdir: cannot create directory ‘/content/drive/My Drive/FF_REAL_Face_only_data’: File exists

# %%
create_face_videos(video_files,'/content/drive/My Drive/FF_REAL_Face_only_data/')
# Out:
# No of videos already present  191
#   0%|          | 0/196 [00:00<?, ?it/s]
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id2_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/0.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/1.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/2.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/3.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/4.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id3_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/5.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/6.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/7.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/8.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/9.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id16_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id3_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id6_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id3_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id17_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id0_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id6_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id1_0009.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0001.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0004.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id17_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id2_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id4_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0002.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id16_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id2_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id4_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id1_id9_0000.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0003.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0005.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0006.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0007.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0008.mp4
# File Already exists:  /content/drive/My Drive/FF_REAL_Face_only_data/id0_id9_0009.mp4
